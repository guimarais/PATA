# %%
import sys
sys.path.append('../InputData/')

# %%
from ParseCalib import read_calib_file

# %%
df = read_calib_file('../data/calib.dat')

# %%
df.head()
# Out:
#             qi01      qi02      qi03      qi04      qi05      qi06      qi07      qi08  ...    vcmzf2    dcolfi   mangxf1   mangyf1   mangzf1   mangxf2   mangyf2   mangzf2
# ID                                                                                      ...
# 500001  0.123737 -3.665007  0.358154 -0.123737 -3.299180 -0.358154  0.085994  3.236029  ... -0.017285  7.107554 -0.001333  0.000298  0.000709 -0.001413  0.000143  0.000906
# 500002 -0.162479 -3.578801 -0.035046  0.162479 -4.146284  0.035046 -0.389997  4.015099  ... -0.045222  7.728730 -0.000055  0.000021  0.000546  0.000005  0.000012 -0.000002
# 500003  0.134875 -1.861337  0.343628 -0.134875 -2.293239 -0.343628 -0.250974  1.999965  ... -0.016176  4.299312  0.000144 -0.000070 -0.000246 -0.002918 -0.000428 -0.002649
# 500004  0.083603 -3.037833  0.132645 -0.083603 -3.626661 -0.132645 -0.060392  3.214813  ... -0.035157  6.643401  0.002461  0.000265 -0.001094  0.000723  0.000065 -0.000127
# ...
